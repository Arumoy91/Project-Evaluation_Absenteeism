# %%
import pandas as pd  # Importing the packages
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('absent.csv')  # Reading the data files
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
df.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#   Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
df.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               740 non-null    int64
#  1   Reason for absence               740 non-null    int64
#  2   Month of absence                 740 non-null    int64
#  3   Day of the week                  740 non-null    int64
#  4   Seasons                          740 non-null    int64
#  5   Transportation expense           740 non-null    int64
#  6   Distance from Residence to Work  740 non-null    int64
#  7   Service time                     740 non-null    int64
#  8   Age                              740 non-null    int64
#  9   Work load Average/day            740 non-null    object
#  10  Hit target                       740 non-null    int64
#  11  Disciplinary failure             740 non-null    int64
# ...

# %%
df.shape
# Out:
# (740, 21)

# %%
df.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
dfcorr=df.corr()  # finding out the correlation between the variables in the dataset.
dfcorr
# Out:
#                                        ID  Reason for absence  \
# ID                               1.000000           -0.064245
# Reason for absence              -0.064245            1.000000
# Month of absence                -0.000043           -0.083858
# Day of the week                  0.034468            0.116319
# Seasons                          0.098495           -0.117925
# Transportation expense          -0.224163           -0.119381
# Distance from Residence to Work -0.486160            0.161831
# Service time                    -0.272704            0.048425
# Age                              0.040899           -0.078608
# Hit target                       0.018789            0.088943
# Disciplinary failure             0.004502           -0.545054
# Education                       -0.036254           -0.047357
# Son                              0.002767           -0.055364
# Social drinker                  -0.451338            0.065441
# ...

# %%
age_abs = df.groupby('Age')[['Absenteeism time in hours']].mean()
ax = age_abs.plot(kind='bar', figsize=(10,8), legend=False)
for i, v in enumerate(age_abs.values):
    ax.text(i-.25, v + 1, str(np.int(np.round(v))), color='red')
ax.set_ylabel('Absenteeism time in hours')
ax.set_title('Average Absenteeism time in hours by age')
plt.show()

# %%
df['Son'].value_counts()
# Out:
# 0    298
# 1    229
# 2    156
# 4     42
# 3     15
# Name: Son, dtype: int64

# %%
plt.figure(figsize=(12,6))
df[df['Son']!=0]['Absenteeism time in hours'].plot.hist(bins=50)

# %%
plt.figure(figsize=(14,6))
df[df['Son']!=0]['Age'].plot.hist(bins=50)

# %%
ax = df.groupby('Age')['Son', 'Pet'].sum().plot(figsize=(10,8))
ax.set_ylabel('Count')
ax.set_title('Count of Pet & Son by Age')
plt.show()
# Out:
# C:\Users\sodainmind\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
import seaborn as sns
sns.countplot(df['Reason for absence'])
absent_percent=round((df['Reason for absence'].value_counts().values[0]/740*100))

# %%
sns.relplot(x='Reason for absence',y="Age",hue='Seasons',data=df)

# %%
sns.distplot(df['Reason for absence'],bins=10)

# %%
sns.jointplot(x='Age',y='Absenteeism time in hours',data=df)

# %%
sns.jointplot(x='Transportation expense',y='Month of absence',data=df,kind='hex',color='blue')

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(),cmap='summer')

# %%
ROA = df.groupby('Reason for absence')

# %%
ROA['Absenteeism time in hours'].max()
# Out:
# Reason for absence
# 0       0
# 1      64
# 2      24
# 3       8
# 4       8
# 5       8
# 6     120
# 7      40
# 8       8
# 9     112
# 10     48
# 11    120
# 12    112
# 13    120
# 14     40
# 15      8
# 16      3
# 17      8
# 18     80
# 19    104
# 21      8
# 22     16
# 23     16
# 24      8
# 25      8
# 26     16
# 27      3
# 28     24
# Name: Absenteeism time in hours, dtype: int64

# %%
print(df['Age'].value_counts()/740*100)
sns.countplot(df['Age'])
# Out:
# 28    15.810811
# 38    15.270270
# 37    10.540541
# 40     7.837838
# 33     6.891892
# 36     6.756757
# 30     6.216216
# 50     5.000000
# 41     4.594595
# 34     3.918919
# 47     3.243243
# 43     3.243243
# 31     2.972973
# 32     1.756757
# 58     1.081081
# 39     1.081081
# 29     0.945946
# 27     0.945946
# 48     0.810811
# 49     0.675676
# 46     0.270270
# 53     0.135135
# Name: Age, dtype: float64

# %%
sns.relplot(x='Reason for absence',y="Service time",hue='Age',data=df)

# %%
df['Social drinker'] = df['Social drinker'].astype('bool')
df['Social smoker'] = df['Social smoker'].astype('bool')
df['Disciplinary failure'] = df['Disciplinary failure'].astype('bool')
df['Seasons'] = df['Seasons'].astype('category')
df['Education'] = df['Education'].astype('category')
df['Day of the week'] = df['Day of the week'].astype('category')
df['Month of absence'] = df['Month of absence'].astype('category')
df['Reason for absence'] = df['Reason for absence'].astype('category')

# %%
df[df['Month of absence']==0]
# Out:
#      ID Reason for absence Month of absence Day of the week Seasons  \
# 737   4                  0                0               3       1
# 738   8                  0                0               4       2
# 739  35                  0                0               6       3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 737                     118                               14            13
# 738                     231                               35            14
# 739                     179                               45            14
#
#      Age Work load Average/day   ...  Disciplinary failure  Education Son  \
# 737   40               2,71,219  ...                 False          1   1
# 738   39               2,71,219  ...                 False          1   2
# 739   53               2,71,219  ...                 False          1   1
#
#      Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# ...

# %%
df[(df['Absenteeism time in hours']==0) & (df['Disciplinary failure']!=1)]
# Out:
#      ID Reason for absence Month of absence Day of the week Seasons  \
# 134  34                 27                1               2       2
# 737   4                  0                0               3       1
# 738   8                  0                0               4       2
# 739  35                  0                0               6       3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 134                     118                               10            10
# 737                     118                               14            13
# 738                     231                               35            14
# 739                     179                               45            14
#
#      Age Work load Average/day   ...  Disciplinary failure  Education Son  \
# 134   37               3,08,593  ...                 False          1   0
# 737   40               2,71,219  ...                 False          1   1
# ...

# %%
season_mapping = {1:'Summer', 2:'Autumn', 3:'Winter', 4:'Spring'}
df['season_name'] = df.Seasons.map(season_mapping)
df['season_name'] = df['season_name'].astype('category')
df.drop_duplicates(['Seasons', 'season_name'])[['Seasons','season_name']]
# Out:
#     Seasons season_name
# 0         1      Summer
# 49        4      Spring
# 111       2      Autumn
# 175       3      Winter

# %%
reason_mapping = {
    0: 'Unknown',
    1: 'Certain infectious and parasitic diseases',
    2: 'Neoplasms',
    3: 'Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism',
    4: 'Endocrine, nutritional and metabolic diseases',
    5: 'Mental and behavioural disorders',
    6: 'Diseases of the nervous system',
    7: 'Diseases of the eye and adnexa',
    8: 'Diseases of the ear and mastoid process',
    9: 'Diseases of the circulatory system',
    10: 'Diseases of the respiratory system',
    11: 'Diseases of the digestive system',
    12: 'Diseases of the skin and subcutaneous tissue',
    13: 'Diseases of the musculoskeletal system and connective tissue',
    14: 'Diseases of the genitourinary system',
    15: 'Pregnancy, childbirth and the puerperium',
    16: 'Certain conditions originating in the perinatal period',
    17: 'Congenital malformations, deformations and chromosomal abnormalities',
    18: 'Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified',
    19: 'Injury, poisoning and certain other consequences of external causes',
    20: 'External causes of morbidity and mortality',
    21: 'Factors influencing health status and contact with health services',
    22: 'Patient follow-up',
    23: 'Medical consultation',
    24: 'Blood donation',
    25: 'Laboratory examination',
    26: 'Unjustified absence',
    27: 'Physiotherapy',
    28: 'Dental consultation'
}
df['reason_text'] = df['Reason for absence'].map(reason_mapping)

# %%
education_mapping = {
    1: 'High School',
    2: 'Graduate',
    3: 'Post Graduate',
    4: 'Master & Doctor'
}
education_list = {'High School', 'Graduate', 'Post Graduate', 'Master & Doctor'}
df['Education_detail'] = df['Education'].map(education_mapping)
#df['Education_detail'] = df['Education_detail'].astype('category')
category_education = pd.api.types.CategoricalDtype(categories=education_list, ordered=True)
df['Education_detail'] = df['Education_detail'].astype(category_education)

# %%
df.head(10)
# Out:
#    ID Reason for absence Month of absence Day of the week Seasons  \
# 0  11                 26                7               3       1
# 1  36                  0                7               3       1
# 2   3                 23                7               4       1
# 3   7                  7                7               5       1
# 4  11                 23                7               5       1
# 5   3                 23                7               6       1
# 6  10                 22                7               6       1
# 7  20                 23                7               6       1
# 8  14                 19                7               2       1
# 9   1                 22                7               2       1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# ...

# %%
reason_abs = df.groupby('reason_text', as_index=False)['Absenteeism time in hours'].sum()
with pd.option_context('display.max_colwidth', -1):
    display(reason_abs.sort_values('Absenteeism time in hours', ascending=False).style.hide_index())
# Out:
# <style  type="text/css" >
# </style><table id="T_d20e6370_22a3_11eb_b5a9_98541b2576d1" ><thead>    <tr>        <th class="col_heading level0 col0" >reason_text</th>        <th class="col_heading level0 col1" >Absenteeism time in hours</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_d20e6370_22a3_11eb_b5a9_98541b2576d1row0_col0" class="data row0 col0" >Diseases of the musculoskeletal system and connective tissue</td>
#                         <td id="T_d20e6370_22a3_11eb_b5a9_98541b2576d1row0_col1" class="data row0 col1" >842</td>
#             </tr>
#             <tr>
#                                 <td id="T_d20e6370_22a3_11eb_b5a9_98541b2576d1row1_col0" class="data row1 col0" >Injury, poisoning and certain other consequences of external causes</td>
#                         <td id="T_d20e6370_22a3_11eb_b5a9_98541b2576d1row1_col1" class="data row1 col1" >729</td>
#             </tr>
#             <tr>
# ...

# %%
mar_abs = df[df['Month of absence']==3].groupby('reason_text', as_index=False)['Absenteeism time in hours'].sum()
with pd.option_context('display.max_colwidth', -1):
    display(mar_abs.sort_values('Absenteeism time in hours', ascending=False).style.hide_index())
# Out:
# <style  type="text/css" >
# </style><table id="T_d2183590_22a3_11eb_bbba_98541b2576d1" ><thead>    <tr>        <th class="col_heading level0 col0" >reason_text</th>        <th class="col_heading level0 col1" >Absenteeism time in hours</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_d2183590_22a3_11eb_bbba_98541b2576d1row0_col0" class="data row0 col0" >Injury, poisoning and certain other consequences of external causes</td>
#                         <td id="T_d2183590_22a3_11eb_bbba_98541b2576d1row0_col1" class="data row0 col1" >147</td>
#             </tr>
#             <tr>
#                                 <td id="T_d2183590_22a3_11eb_bbba_98541b2576d1row1_col0" class="data row1 col0" >Diseases of the musculoskeletal system and connective tissue</td>
#                         <td id="T_d2183590_22a3_11eb_bbba_98541b2576d1row1_col1" class="data row1 col1" >136</td>
#             </tr>
#             <tr>
# ...

# %%
jul_abs = df[df['Month of absence']==7].groupby('reason_text', as_index=False)['Absenteeism time in hours'].sum()
with pd.option_context('display.max_colwidth', -1):
    display(jul_abs.sort_values('Absenteeism time in hours', ascending=False).style.hide_index())
# Out:
# <style  type="text/css" >
# </style><table id="T_d22eb5ba_22a3_11eb_91ac_98541b2576d1" ><thead>    <tr>        <th class="col_heading level0 col0" >reason_text</th>        <th class="col_heading level0 col1" >Absenteeism time in hours</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_d22eb5ba_22a3_11eb_91ac_98541b2576d1row0_col0" class="data row0 col0" >Diseases of the nervous system</td>
#                         <td id="T_d22eb5ba_22a3_11eb_91ac_98541b2576d1row0_col1" class="data row0 col1" >128</td>
#             </tr>
#             <tr>
#                                 <td id="T_d22eb5ba_22a3_11eb_91ac_98541b2576d1row1_col0" class="data row1 col0" >Diseases of the circulatory system</td>
#                         <td id="T_d22eb5ba_22a3_11eb_91ac_98541b2576d1row1_col1" class="data row1 col1" >112</td>
#             </tr>
#             <tr>
# ...

# %%
df_add = df[['Reason for absence', 'Month of absence', 'Day of the week', 'Seasons', 'Transportation expense', 
        'Distance from Residence to Work', 'Service time', 'Age',  'Hit target',
        'Disciplinary failure', 'Education', 'Son', 'Social drinker', 'Social smoker', 'Pet', 'Weight', 
        'Height', 'Body mass index' ]]

# %%
X = df_add

# %%
y = df['Absenteeism time in hours']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rder = RandomForestClassifier()

# %%
rder.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred = rder.predict(X_test)

# %%
from sklearn.metrics import  mean_squared_error as MSE

# %%
rmse_test = MSE(y_test, y_pred) ** (1/2)

# %%
print(f'Test set of RMSE : {rmse_test:.2f}')
# Out:
# Test set of RMSE : 13.77

# %%
from sklearn import metrics
from sklearn.metrics import classification_report

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.4864864864864865

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.38      0.26      0.31        19
#            2       0.50      0.45      0.48        33
#            3       0.35      0.37      0.36        19
#            4       0.23      0.25      0.24        12
#            5       0.50      0.50      0.50         2
#            7       0.00      0.00      0.00         0
#            8       0.57      0.71      0.63        42
#           16       0.00      0.00      0.00         3
#           24       1.00      0.25      0.40         4
#           32       0.00      0.00      0.00         1
#           40       0.00      0.00      0.00         1
#           64       0.00      0.00      0.00         0
#           80       0.00      0.00      0.00         2
#          112       0.00      0.00      0.00         0
#
#     accuracy                           0.49       148
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dr = DecisionTreeClassifier()

# %%
dr.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
dr.score(X_test,y_test)
# Out:
# 0.40540540540540543

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.38      0.26      0.31        19
#            2       0.50      0.45      0.48        33
#            3       0.35      0.37      0.36        19
#            4       0.23      0.25      0.24        12
#            5       0.50      0.50      0.50         2
#            7       0.00      0.00      0.00         0
#            8       0.57      0.71      0.63        42
#           16       0.00      0.00      0.00         3
#           24       1.00      0.25      0.40         4
#           32       0.00      0.00      0.00         1
#           40       0.00      0.00      0.00         1
#           64       0.00      0.00      0.00         0
#           80       0.00      0.00      0.00         2
#          112       0.00      0.00      0.00         0
#
#     accuracy                           0.49       148
# ...
